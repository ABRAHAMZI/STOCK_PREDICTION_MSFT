# %% [markdown]
# # installations and importing data

# %% [markdown]
# pdr.data.get_data_yahoo('MSFT')
#
# import pandas_datareader as pdr
# data = pdr.get_data_yahoo('AAPL')  # Fetch data for Apple (AAPL) as a test
# print(data.head())
#
# df=dr.data.get_data_yahoo('ibm',start='2018-09-27', end='2018-10-23')
#
# import pandas_datareader as pdr
# end="2022-12-15"
# start="2022-12-15"
# stock_list=['TATAELXSI.NS']
# data=pdr.get_data_yahoo(symbols=stock_list,start=start,end=end)
# print(data)

# %%
pip install git+https://github.com/pydata/pandas-datareader.git
# Out:
# ...
#   Cloning https://github.com/pydata/pandas-datareader.git to c:\users\abraham-ziegen\appdata\local\temp\pip-req-build-r22gvfak
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Error [WinError 2] The system cannot find the file specified while executing command git version
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?

# %%
import pandas_datareader as pdr
pdr.get_data_fred('GS10')
# Out:
#             GS10
# DATE
# 2019-05-01  2.40
# 2019-06-01  2.07
# 2019-07-01  2.06
# 2019-08-01  1.63
# 2019-09-01  1.70
# 2019-10-01  1.71
# 2019-11-01  1.81
# 2019-12-01  1.86
# 2020-01-01  1.76
# 2020-02-01  1.50
# 2020-03-01  0.87
# 2020-04-01  0.66
# 2020-05-01  0.67
# 2020-06-01  0.73
# 2020-07-01  0.62
# 2020-08-01  0.65
# 2020-09-01  0.68
# 2020-10-01  0.79
# 2020-11-01  0.87
# 2020-12-01  0.93
# 2021-01-01  1.08
# 2021-02-01  1.26
# 2021-03-01  1.61
# 2021-04-01  1.64
# 2021-05-01  1.62
# 2021-06-01  1.52
# 2021-07-01  1.32
# 2021-08-01  1.28
# 2021-09-01  1.37
# 2021-10-01  1.58
# 2021-11-01  1.56
# 2021-12-01  1.47
# 2022-01-01  1.76
# 2022-02-01  1.93
# 2022-03-01  2.13
# 2022-04-01  2.75
# 2022-05-01  2.90
# 2022-06-01  3.14
# 2022-07-01  2.90
# 2022-08-01  2.90
# 2022-09-01  3.52
# 2022-10-01  3.98
# 2022-11-01  3.89
# 2022-12-01  3.62
# 2023-01-01  3.53
# 2023-02-01  3.75
# 2023-03-01  3.66
# 2023-04-01  3.46
# 2023-05-01  3.57
# 2023-06-01  3.75
# 2023-07-01  3.90
# ...

# %%
# !pip install pandas-datareader
# Out:
# ...
#   Obtaining dependency information for pandas-datareader from https://files.pythonhosted.org/packages/3f/16/56c9d648b503619ebe96f726b5f642b68e299b34162ed2d6faa9d7966b7d/pandas_datareader-0.10.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#    ------- -------------------------------- 20.5/109.5 kB ? eta -:--:--
#    -------------- ------------------------ 41.0/109.5 kB 653.6 kB/s eta 0:00:01
#    ----------------------------- --------- 81.9/109.5 kB 762.6 kB/s eta 0:00:01
#    ----------------------------- --------- 81.9/109.5 kB 762.6 kB/s eta 0:00:01
#    ----------------------------------- -- 102.4/109.5 kB 492.8 kB/s eta 0:00:01
#    ----------------------------------- -- 102.4/109.5 kB 492.8 kB/s eta 0:00:01
#    -------------------------------------- 109.5/109.5 kB 396.9 kB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
api_key="7bd505f465ea6c7d3e447249d9af43a11c48049c"

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"D:\pga_31\capstone 2\MSFT.csv")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060163  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062311   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063386   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061774    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060700    47894400

# %%
df.shape
# Out:
# (9584, 7)

# %% [markdown]
# # loading data from source
# we use the yahoo finance to get data of stock market for microsoft AKA (MSFT) historical data- MSFT is a ticker name uniquely identify stock names .

# %%
import pandas_datareader as pdr
from datetime import datetime

# %%
import pandas as pd 
import pandas_datareader as dr
# %matplotlib inline

# %%
import time
import datetime
import pandas as pd

query_string='https://query1.finance.yahoo.com/v7/finance/download/MSFT?period1=511108200&period2=1713357655&interval=1d&events=history&includeAdjustedClose=true'
df1=pd.read_csv(query_string)

ticker='MSFT'
period1=int(time.mktime(datetime.datetime(2024,4,1,23,59).timetuple()))
period2=int(time.mktime(datetime.datetime(2024,4,16,23,59).timetuple()))
query_string1=f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={period1}&period2={period2}&interval=1d&events=history&includeAdjustedClose=true'
df2=pd.read_csv(query_string1)

# %% [markdown]
# this provides the maximum data available to us. as we specified the duration as max in historial data of yahoo finance website. it provides all the available data in yahoo finance for the  ticker name(MSFT)

# %%
df1.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060163  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062311   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063386   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061774    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060700    47894400

# %% [markdown]
# this give the data for the duration we specified

# %%
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2024-04-01  423.950012  427.890015  422.220001  424.570007  424.570007
# 1  2024-04-02  420.109985  422.380005  417.839996  421.440002  421.440002
# 2  2024-04-03  419.730011  423.260010  419.089996  420.450012  420.450012
# 3  2024-04-04  424.989990  428.670013  417.570007  417.880005  417.880005
# 4  2024-04-05  420.010010  426.510010  418.320007  425.519989  425.519989
#
#      Volume
# 0  16316000
# 1  17912000
# 2  16502300
# 3  19370900
# 4  16544300

# %% [markdown]
# ## Finding missing dates in the data

# %%
min_date = df['Date'].min()
max_date = df['Date'].max()
date_range = pd.date_range(start=min_date, end=max_date)

missing_dates = date_range[~date_range.isin(df['Date'])]
missing_dates_list = missing_dates.tolist()
print("Missing dates:")
# Out:
# Missing dates:

# %%
missing_dates
# Out:
# DatetimeIndex(['1986-03-15', '1986-03-16', '1986-03-22', '1986-03-23',
#                '1986-03-28', '1986-03-29', '1986-03-30', '1986-04-05',
#                '1986-04-06', '1986-04-12',
#                ...
#                '2024-02-18', '2024-02-19', '2024-02-24', '2024-02-25',
#                '2024-03-02', '2024-03-03', '2024-03-09', '2024-03-10',
#                '2024-03-16', '2024-03-17'],
#               dtype='datetime64[ns]', length=4306, freq=None)

# %%
missing_dates_list
# Out:
# [Timestamp('1986-03-15 00:00:00'),
#  Timestamp('1986-03-16 00:00:00'),
#  Timestamp('1986-03-22 00:00:00'),
#  Timestamp('1986-03-23 00:00:00'),
#  Timestamp('1986-03-28 00:00:00'),
#  Timestamp('1986-03-29 00:00:00'),
#  Timestamp('1986-03-30 00:00:00'),
#  Timestamp('1986-04-05 00:00:00'),
#  Timestamp('1986-04-06 00:00:00'),
#  Timestamp('1986-04-12 00:00:00'),
#  Timestamp('1986-04-13 00:00:00'),
#  Timestamp('1986-04-19 00:00:00'),
#  Timestamp('1986-04-20 00:00:00'),
#  Timestamp('1986-04-26 00:00:00'),
#  Timestamp('1986-04-27 00:00:00'),
#  Timestamp('1986-05-03 00:00:00'),
#  Timestamp('1986-05-04 00:00:00'),
#  Timestamp('1986-05-10 00:00:00'),
#  Timestamp('1986-05-11 00:00:00'),
#  Timestamp('1986-05-17 00:00:00'),
#  Timestamp('1986-05-18 00:00:00'),
#  Timestamp('1986-05-24 00:00:00'),
#  Timestamp('1986-05-25 00:00:00'),
#  Timestamp('1986-05-26 00:00:00'),
#  Timestamp('1986-05-31 00:00:00'),
#  Timestamp('1986-06-01 00:00:00'),
#  Timestamp('1986-06-07 00:00:00'),
# ...

# %%
len(missing_dates_list)
# Out:
# 4306

# %%
df.shape
# Out:
# (9584, 7)

# %%
missing_dates_df['Quarter'] = missing_dates_df['Date'].dt.quarter
missing_dates_df['Year'] = missing_dates_df['Date'].dt.year
missing_dates_df['Month']=missing_dates_df['Date'].dt.month
missing_dates_df['Week'] = missing_dates_df['Date'].dt.week
# Out:
# C:\Users\ABRAHAM-ZIEGEN\AppData\Local\Temp\ipykernel_16760\2927228271.py:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   missing_dates_df['Week'] = missing_dates_df['Date'].dt.week

# %%
missing_dates_df
# Out:
#            Date  Year  Quarter  Month  Week
# 0    1986-03-15  1986        1      3    11
# 1    1986-03-16  1986        1      3    11
# 2    1986-03-22  1986        1      3    12
# 3    1986-03-23  1986        1      3    12
# 4    1986-03-28  1986        1      3    13
# ...         ...   ...      ...    ...   ...
# 4301 2024-03-03  2024        1      3     9
# 4302 2024-03-09  2024        1      3    10
# 4303 2024-03-10  2024        1      3    10
# 4304 2024-03-16  2024        1      3    11
# 4305 2024-03-17  2024        1      3    11
#
# [4306 rows x 5 columns]

# %%
missing_Quarter
# Out:
#             0
# Quarter
# 1        1090
# 2        1058
# 3        1079
# 4        1079

# %%
import matplotlib.pyplot as plt
plt.plot(missing_Quarter)

# %%
missing_Quarter=pd.DataFrame(missing_dates_df.groupby('Quarter').size())
missing_in_year=pd.DataFrame(missing_dates_df.groupby('Year').size())
missing_in_month=pd.DataFrame(missing_dates_df.groupby('Month').size())
missing_in_week=pd.DataFrame(missing_dates_df.groupby('Week').size())

# %%
missing_in_year
# Out:
#         0
# Year
# 1986   90
# 1987  112
# 1988  113
# 1989  113
# 1990  112
# 1991  112
# 1992  112
# 1993  112
# 1994  113
# 1995  113
# 1996  112
# 1997  112
# 1998  113
# 1999  113
# 2000  114
# 2001  117
# 2002  113
# 2003  113
# 2004  114
# 2005  113
# 2006  114
# 2007  114
# 2008  113
# 2009  113
# 2010  113
# 2011  113
# 2012  116
# 2013  113
# 2014  113
# 2015  113
# 2016  114
# 2017  114
# 2018  114
# 2019  113
# 2020  113
# 2021  113
# 2022  114
# 2023  115
# 2024   25

# %%
print(missing_in_year.mean(),"\n",missing_in_year.max(),"\n",missing_in_year.min())
# Out:
# 0    110.410256
# dtype: float64
#  0    117
# dtype: int64
#  0    25
# dtype: int64

# %% [markdown]
# The total number of data missing in a year id
# 110 on a average
# 117 on highest
# 25 on lowest

# %%
plt.figure(figsize=(20,10))
plt.plot(missing_in_year)

# %%
sns.boxplot(missing_in_year)
# Out:
# <Axes: >

# %%
missing_in_month
# Out:
#          0
# Month
# 1      398
# 2      345
# 3      347
# 4      356
# 5      375
# 6      327
# 7      376
# 8      336
# 9      367
# 10     340
# 11     363
# 12     376

# %%
print(missing_in_month.mean()/38,'\n',missing_in_month.max()/38,'\n',missing_in_month.min()/38)
# Out:
# 0    9.442982
# dtype: float64
#  0    10.473684
# dtype: float64
#  0    8.605263
# dtype: float64

# %%
plt.plot(missing_in_month)

# %% [markdown]
# THUS we see on an average we don't get 8 to 10 days from a month

# %%
missing_in_week
# Out:
#         0
# Week
# 1     104
# 2      76
# 3      92
# 4      87
# 5      76
# 6      76
# 7      82
# 8     108
# 9      76
# 10     76
# 11     78
# 12     80
# 13     87
# 14     82
# 15     86
# 16     83
# 17     77
# 18     76
# 19     76
# 20     76
# 21     76
# 22    113
# 23     77
# 24     77
# 25     78
# 26     76
# 27    113
# 28     77
# 29     76
# 30     76
# 31     76
# 32     76
# 33     76
# 34     76
# 35     76
# 36    107
# 37     87
# 38     76
# 39     76
# 40     76
# 41     76
# 42     76
# 43     76
# 44     78
# 45     76
# 46     76
# 47     97
# 48     93
# 49     77
# 50     76
# 51     80
# 52    110
# 53     20

# %%
print(missing_in_week.mean()/38,"\n",missing_in_week.max()/38,'\n',missing_in_week.min()/38)
# Out:
# 0    2.138034
# dtype: float64
#  0    2.973684
# dtype: float64
#  0    0.526316
# dtype: float64

# %%
plt.plot(missing_in_week)

# %% [markdown]
# IN Average we see close to 0 to  3 days the data in not available

# %%
min_date = df['Date'].min()
max_date = df['Date'].max()

date_range = pd.date_range(start=min_date, end=max_date)
missing_dates = date_range[~date_range.isin(df['Date'])]

missing_dates_df = pd.DataFrame({'Date': missing_dates})
missing_dates_df['Year'] = missing_dates_df['Date'].dt.year
missing_dates_df['Quarter'] = missing_dates_df['Date'].dt.quarter

missing_dates_quarters_counts = missing_dates_df.groupby(['Year', 'Quarter']).size().reset_index(name='Count')
missing_dates_pivot = missing_dates_quarters_counts.pivot(index='Year', columns='Quarter', values='Count')
missing_dates_pivot = missing_dates_pivot.fillna(0)

print("Count of missing dates for each quarter:")
missing_dates_pivot
# Out:
# Count of missing dates for each quarter:
# Quarter     1     2     3     4
# Year
# 1986      7.0  27.0  28.0  28.0
# 1987     28.0  28.0  28.0  28.0
# 1988     28.0  28.0  28.0  29.0
# 1989     28.0  27.0  29.0  29.0
# 1990     27.0  28.0  29.0  28.0
# 1991     29.0  27.0  28.0  28.0
# 1992     28.0  28.0  28.0  28.0
# 1993     28.0  28.0  28.0  28.0
# 1994     27.0  29.0  28.0  29.0
# 1995     27.0  28.0  29.0  29.0
# 1996     28.0  28.0  28.0  28.0
# 1997     29.0  27.0  28.0  28.0
# 1998     29.0  28.0  28.0  28.0
# 1999     29.0  28.0  28.0  28.0
# 2000     28.0  28.0  29.0  29.0
# 2001     28.0  28.0  33.0  28.0
# 2002     30.0  27.0  28.0  28.0
# 2003     29.0  28.0  28.0  28.0
# 2004     29.0  29.0  28.0  28.0
# 2005     29.0  27.0  28.0  29.0
# 2006     28.0  28.0  29.0  29.0
# 2007     29.0  28.0  29.0  28.0
# 2008     30.0  27.0  28.0  28.0
# 2009     29.0  28.0  28.0  28.0
# 2010     29.0  28.0  28.0  28.0
# 2011     28.0  28.0  28.0  29.0
# ...

# %%
missing_dates_grouped
# Out:
#     Quarter  Count
# 0    1986Q1      7
# 1    1986Q2     27
# 2    1986Q3     28
# 3    1986Q4     28
# 4    1987Q1     28
# ..      ...    ...
# 148  2023Q1     28
# 149  2023Q2     29
# 150  2023Q3     29
# 151  2023Q4     29
# 152  2024Q1     25
#
# [153 rows x 2 columns]

# %% [markdown]
# ## findings
# many days are missing in the historical data
# The total number of data missing in a year id
# 1. 110 on a average-117 on highest-25 on lowest(only quarter year has passed so far)
# 2. we see on an average we don't get 8 to 10 days from a month
# 3. we see close to 0 to 3 days on a week data in not available
#
# ## important reasons:
# 1. weekends ,vacation and holidays
# 2. corporal changes (stock splits, mergers, acquisitions, or delistings)needs updating and data providers update the information
# 3. data availability (by license and restrictions) and removing errors provided to services
#
# (Since Yahoo Finance is used by many investors world wide for stock market analysis, they are working to provide reliable data only. So when there is a reason for data becoming inaccurate its resource credibility is affected . so they only share reliable up to date information and data given to them by fortunate understanding between the companies and their progress)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9584 entries, 0 to 9583
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9584 non-null   object
#  1   Open       9584 non-null   float64
#  2   High       9584 non-null   float64
#  3   Low        9584 non-null   float64
#  4   Close      9584 non-null   float64
#  5   Adj Close  9584 non-null   float64
#  6   Volume     9584 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 524.3+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  9584.000000  9584.000000  9584.000000  9584.000000  9584.000000
# mean     55.005557    55.583425    54.418247    55.023365    49.460465
# std      83.220175    84.030680    82.382276    83.256229    83.275602
# min       0.088542     0.092014     0.088542     0.090278     0.055866
# 25%       5.630860     5.693604     5.507813     5.609375     3.471190
# 50%      27.250000    27.500000    27.000000    27.260000    19.140273
# 75%      45.980000    46.560626    45.482501    46.042500    36.839192
# max     429.829987   430.820007   427.160004   429.369995   429.369995
#
#              Volume
# count  9.584000e+03
# mean   5.712408e+07
# std    3.813792e+07
# min    2.304000e+06
# 25%    3.258015e+07
# 50%    5.024705e+07
# 75%    7.108200e+07
# max    1.031789e+09

# %% [markdown]
# # necessary columns

# %%
df3 = df[['Date', 'Close']]
df3
# Out:
#            Date       Close
# 0    1986-03-13    0.097222
# 1    1986-03-14    0.100694
# 2    1986-03-17    0.102431
# 3    1986-03-18    0.099826
# 4    1986-03-19    0.098090
# ...         ...         ...
# 9579 2024-03-18  417.320007
# 9580 2024-03-19  421.410004
# 9581 2024-03-20  425.230011
# 9582 2024-03-21  429.369995
# 9583 2024-03-22  428.739990
#
# [9584 rows x 2 columns]

# %%
import datetime

def str_to_datetime(s):
    split = s.split('-')
    year, month, day = int(split[0]), int(split[1]), int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2024-04-17')
datetime_object
# Out:
# datetime.datetime(2024, 4, 17, 0, 0)

# %%
df3['Date']=df3['Date'].apply(str_to_datetime)
df3['Date']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df3['Date']=df3['Date'].apply(str_to_datetime)
#       2 df3['Date']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# ...

# %%
df3['Date'] = df3['Date'].apply(str_to_datetime)
df3['Date']
# Out:
# C:\Users\ABRAHAM-ZIEGEN\AppData\Local\Temp\ipykernel_15584\1580823957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Date'] = df3['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9579   2024-03-18
# 9580   2024-03-19
# 9581   2024-03-20
# 9582   2024-03-21
# 9583   2024-03-22
# Name: Date, Length: 9584, dtype: datetime64[ns]

# %%
import datetime

def str_to_datetime(s):
    split=s.split('-')
    year,month,day=int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year,month=month,day=day)

datetime_object=str_to_datetime('2024-04-17')
datetime_object
# Out:
# datetime.datetime(2024, 4, 17, 0, 0)

# %%
df['Date']=df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9579   2024-03-18
# 9580   2024-03-19
# 9581   2024-03-20
# 9582   2024-03-21
# 9583   2024-03-22
# Name: Date, Length: 9584, dtype: datetime64[ns]

# %%
df=df[['Date','Close']]

# %%
df
# Out:
#            Date       Close
# 0    1986-03-13    0.097222
# 1    1986-03-14    0.100694
# 2    1986-03-17    0.102431
# 3    1986-03-18    0.099826
# 4    1986-03-19    0.098090
# ...         ...         ...
# 9579 2024-03-18  417.320007
# 9580 2024-03-19  421.410004
# 9581 2024-03-20  425.230011
# 9582 2024-03-21  429.369995
# 9583 2024-03-22  428.739990
#
# [9584 rows x 2 columns]

# %%
df3.index = df3.pop('Date')
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2024-03-18  417.320007
# 2024-03-19  421.410004
# 2024-03-20  425.230011
# 2024-03-21  429.369995
# 2024-03-22  428.739990
#
# [9584 rows x 1 columns]

# %%
df3

# %%
import matplotlib.pyplot as plt

plt.plot(df3.index, df3['Close'])

# %%
api_key="7bd505f465ea6c7d3e447249d9af43a11c48049c"

# %%
import pandas_datareader as pdr

# %%
df4=pdr.get_data_tiingo("MSFT",api_key=api_key)
# Out:
# C:\Users\ABRAHAM-ZIEGEN\AppData\Local\Temp\ipykernel_16760\978754992.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df4=pdr.get_data_tiingo("MSFT",api_key=api_key)

# %%
df4.to_csv("MSFT.csv")

# %%
df5=pd.read_csv("MSFT.csv")

# %%
df5.head()
# Out:
#   symbol                       date   close    high     low    open    volume  \
# 0   MSFT  2019-04-26 00:00:00+00:00  129.89  130.52  129.02  129.70  23654933
# 1   MSFT  2019-04-29 00:00:00+00:00  129.77  130.18  129.35  129.90  16324183
# 2   MSFT  2019-04-30 00:00:00+00:00  130.60  130.70  129.39  129.81  24166503
# 3   MSFT  2019-05-01 00:00:00+00:00  127.88  130.65  127.70  130.53  26821692
# 4   MSFT  2019-05-02 00:00:00+00:00  126.21  128.00  125.52  127.98  27350161
#
#      adjClose     adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# 0  123.622004  124.221602  122.793987  123.441172   23654933      0.0
# 1  123.507795  123.898010  123.108062  123.631521   16324183      0.0
# 2  124.297742  124.392916  123.146132  123.545864   24166503      0.0
# 3  121.708999  124.345329  121.537685  124.231120   26821692      0.0
# 4  120.119587  121.823208  119.462883  121.804173   27350161      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# ...

# %%
df5.tail(5)
# Out:
#      symbol                       date   close    high     low     open  \
# 1252   MSFT  2024-04-17 00:00:00+00:00  411.84  418.88  410.33  417.250
# 1253   MSFT  2024-04-18 00:00:00+00:00  404.27  411.89  403.95  410.630
# 1254   MSFT  2024-04-19 00:00:00+00:00  399.12  405.48  397.77  404.030
# 1255   MSFT  2024-04-22 00:00:00+00:00  400.96  402.85  395.75  400.080
# 1256   MSFT  2024-04-23 00:00:00+00:00  407.57  408.20  403.06  404.235
#
#         volume  adjClose  adjHigh  adjLow  adjOpen  adjVolume  divCash  \
# 1252  15855485    411.84   418.88  410.33  417.250   15855485      0.0
# 1253  21029917    404.27   411.89  403.95  410.630   21029917      0.0
# 1254  30565789    399.12   405.48  397.77  404.030   30565789      0.0
# 1255  20286875    400.96   402.85  395.75  400.080   20286875      0.0
# 1256  15734501    407.57   408.20  403.06  404.235   15734501      0.0
#
#       splitFactor
# 1252          1.0
# 1253          1.0
# 1254          1.0
# 1255          1.0
# ...

# %%
df5.shape
# Out:
# (1257, 14)

# %%
# LSTM IS SENSITIVE TO SCALE OF DATA

# %%
df6=df5.reset_index()['close']

# %%
df6
# Out:
# 0       129.89
# 1       129.77
# 2       130.60
# 3       127.88
# 4       126.21
#          ...
# 1252    411.84
# 1253    404.27
# 1254    399.12
# 1255    400.96
# 1256    407.57
# Name: close, Length: 1257, dtype: float64

# %%
df6.shape
# Out:
# (1257,)

# %%
import matplotlib.pyplot as plt
plt.plot(df6)

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df7=scaler.fit_transform(np.array(df6).reshape(-1,1))

# %%
df7
# Out:
# array([[0.03246858],
#        [0.0320809 ],
#        [0.03476238],
#        ...,
#        [0.90227119],
#        [0.90821568],
#        [0.92957064]])

# %%
print(df7)
# Out:
# [[0.03246858]
#  [0.0320809 ]
#  [0.03476238]
#  ...
#  [0.90227119]
#  [0.90821568]
#  [0.92957064]]

# %% [markdown]
# in time series we should divide data into-
# train and test//
# first part of data -train , remaining-test

# %% [markdown]
# # training model and predicting test data

# %%
training_size=int(len(df7)*0.65)
test_size=len(df7)-training_size
train_data,test_data=df7[0:training_size,:],df7[training_size:len(df7),:1]

# %%
training_size,test_size
# Out:
# (817, 440)

# %%
train_data
# Out:
# array([[0.03246858],
#        [0.0320809 ],
#        [0.03476238],
#        [0.02597487],
#        [0.02057959],
#        [0.02927018],
#        [0.02684716],
#        [0.0183504 ],
#        [0.0183181 ],
#        [0.01828579],
#        [0.02355184],
#        [0.01133977],
#        [0.01579815],
#        [0.01996575],
#        [0.0293671 ],
#        [0.0265887 ],
#        [0.0206119 ],
#        [0.02280877],
#        [0.02529642],
#        [0.02048267],
#        [0.02067651],
#        [0.02041805],
#        [0.01647659],
#        [0.01902885],
#        [0.01240591],
#        [0.        ],
#        [0.01072594],
#        [0.01935192],
#        [0.02578102],
#        [0.03734695],
#        [0.04122379],
#        [0.03960844],
#        [0.03763771],
#        [0.04031919],
#        [0.04073919],
#        [0.04203147],
#        [0.04949439],
#        [0.05120667],
#        [0.05527736],
#        [0.05534197],
#        [0.05795884],
#        [0.04390528],
#        [0.04552063],
# ...

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (716, 100)
# (716,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (339, 100)
# (339,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 49s 596ms/step - loss: 0.0464 - accuracy: 0.0000e+00 - val_loss: 0.0564 - val_accuracy: 0.0029
# Epoch 2/100
# 12/12 [==============================] - 2s 161ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0029
# Epoch 3/100
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0040 - accuracy: 0.0000e+00 - val_loss: 0.0151 - val_accuracy: 0.0029
# Epoch 4/100
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 0.0029
# Epoch 5/100
# 12/12 [==============================] - 2s 157ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0043 - val_accuracy: 0.0029
# Epoch 6/100
# 12/12 [==============================] - 2s 165ms/step - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 0.0036 - val_accuracy: 0.0029
# Epoch 7/100
# ...

# %% [markdown]
# using accuracy score in LSTM model is not quite helpful

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# ...
# 11/11 [==============================] - 0s 32ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 241.14411774345348

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 332.81950744720683

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df7)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df7)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df7)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df7))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(df7), label='Actual Data')  
plt.plot(trainPredictPlot, label='Training Predictions')  
plt.plot(testPredictPlot, label='Test Predictions')  
plt.legend()
plt.show()

# %%
len(test_data)
# Out:
# 440

# %%
440-100
# Out:
# 340

# %%
pd.DataFrame(test_data).tail()
# Out:
#             0
# 435  0.943366
# 436  0.918909
# 437  0.902271
# 438  0.908216
# 439  0.929571

# %% [markdown]
# # predict future data

# %%
x_input=test_data[340:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
len(temp_input)
# Out:
# 100

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])# shifting one position
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))#reshaping form scalar transform
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
print(lst_output)
# Out:
# [0.8895303]
# 101
# 1 day input [0.83697865 0.82276354 0.80541466 0.81633444 0.80431622 0.81126224
#  0.82185895 0.81239298 0.82234355 0.82231125 0.7950441  0.81055148
#  0.81675443 0.81872516 0.8101961  0.81962976 0.82298969 0.82324815
#  0.82134203 0.82525119 0.82770652 0.81100378 0.81013149 0.80153782
#  0.80092398 0.82334507 0.82689885 0.84944916 0.85545828 0.86786418
#  0.87367945 0.87109489 0.88530999 0.90081737 0.89383905 0.90156043
#  0.91338481 0.92084774 0.91781087 0.93651665 0.93286596 0.8972959
#  0.91732627 0.94136271 0.92336769 0.92285077 0.95050561 0.95069945
#  0.97150519 0.95441476 0.92553226 0.93577359 0.92630763 0.91823087
#  0.91412787 0.91215714 0.94275191 0.93851969 0.92947372 0.92927988
#  0.93005525 0.94918102 0.95519013 0.95331632 0.91367557 0.91186638
#  0.93464285 0.92520919 0.91971699 0.95447937 0.95389785 0.98659258
#  0.95816238 0.96107001 0.97428359 0.98662488 1.         0.99796466
#  0.97896811 0.97505896 0.97434821 0.97205441 0.98449262 0.97438051
# ...

# %%
len(temp_input)
# Out:
# 101

# %%
len(lst_output)
# Out:
# 30

# %%
101+30
# Out:
# 131

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
import matplotlib.pyplot as plt

# %%
len(df7)
# Out:
# 1257

# %%
plt.plot(day_new,scaler.inverse_transform(df7[1157:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df8=scaler.inverse_transform(df8).tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 df8=scaler.inverse_transform(df8).tolist()
#
# NameError: name 'df8' is not defined

# %%
plt.plot(df8)

# %%
df8=df7.tolist()
df8.extend(lst_output)
plt.plot(df8[1200:])
